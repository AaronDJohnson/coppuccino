# %%
import jax
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from coppuccino.copula_flows import normalizing_flows_fit
import corner

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
chain = np.loadtxt('/Users/aaron/Documents/GitHub/coppuccino/examples/data/catalog_source_9.txt')

# %%
chain = chain[~np.isnan(chain).any(axis=(1))]

# %%
flow = normalizing_flows_fit(chain, max_epochs=400)
# Out:
#  55%|█████▌    | 221/400 [00:13<00:10, 16.32it/s, train=9.62, val=10.5 (Max patience reached)]
